# %%
import pandas as p

# %%
df= p.read_excel('in_chemico_dataset_processed.xlsx')
# df.describe()
df= df.dropna(axis=1,how='all')
df=df.drop(['Unnamed: 8', 'Unnamed: 9', 'Unnamed: 11'],axis=1)
constant_cols = df.columns[df.nunique() == 1]
df = df.drop(columns=constant_cols.to_list())
df = df.drop(columns=['Name','IUPAC name','CAS registry number','Structure','SMILES code','Sources','Note'])
# Out:
# Index(['Phototoxicity', 'MaxAbsEStateIndex', 'MaxEStateIndex',
#        'MinAbsEStateIndex', 'MinEStateIndex', 'qed', 'SPS', 'MolWt',
#        'HeavyAtomMolWt', 'ExactMolWt',
#        ...
#        'fr_sulfonamd', 'fr_sulfone', 'fr_tetrazole', 'fr_thiazole',
#        'fr_thiophene', 'fr_unbrch_alkane', 'fr_urea', 'Morgan2048',
#        'RDkit2048', 'MoleculeStatus'],
#       dtype='object', length=195)

# %%
y =df['Phototoxicity']
x =df.drop(columns='Phototoxicity')

print("Features shape:", x.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (162, 194)
# Target shape: (162,)
