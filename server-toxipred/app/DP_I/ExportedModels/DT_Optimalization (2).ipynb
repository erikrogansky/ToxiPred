# %%
import sys
import os


sys.path.append(os.path.abspath(r"C:\Users\sofi loran\Documents\Model TP"))
from imports import *

# %%
file_path = 'Rabbit_B_SHAP_DT.xlsx' 
df = pd.read_excel(file_path)
df.head()
# Out:
#     BertzCT  HallKierAlpha   NOCount  EState_VSA3  VSA_EState8  \
# 0  0.089220       0.511069  0.182574     0.000000     0.256948
# 1  0.146317       0.462893  0.258199     0.232360     0.212267
# 2  0.496390       0.283431  0.365148     0.385749     0.047926
# 3  0.435679       0.295994  0.483046     0.216291     0.000000
# 4  0.402744       0.361936  0.447214     0.290634     0.261484
#
#    MinPartialCharge  PEOE_VSA1  FpDensityMorgan3  PEOE_VSA9  Irritation
# 0          0.574868   0.196324          0.595823   0.000000           1
# 1          0.684832   0.178444          0.743926   0.230156           1
# 2          0.627533   0.261267          0.695162   0.361580           0
# 3          0.683098   0.315318          0.700246   0.385121           0
# 4          0.579127   0.189052          0.651106   0.205850           0

# %%
df.shape
# Out:
# (857, 10)

# %%
df.columns.to_list()
# Out:
# ['BertzCT',
#  'HallKierAlpha',
#  'NOCount',
#  'EState_VSA3',
#  'VSA_EState8',
#  'MinPartialCharge',
#  'PEOE_VSA1',
#  'FpDensityMorgan3',
#  'PEOE_VSA9',
#  'Irritation']

# %%
# Define features (X) and target variable (y)
X = df.drop(columns=['Irritation']) 
y = df['Irritation']

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# Print the shapes of the resulting sets
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (685, 9)
# Shape of X_test: (172, 9)
# Shape of y_train: (685,)
# Shape of y_test: (172,)

# %%
def objective(trial):
    # Define hyperparameter search space
    params = {
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy"]), 
        "max_depth": trial.suggest_int("max_depth", 5, 15),  
        "min_samples_split": trial.suggest_int("min_samples_split", 5, 20), 
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 5, 15),
        "max_features": trial.suggest_categorical("max_features", [None, "sqrt", "log2", 0.3, 0.5]), 
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 5, 20),  
        "min_impurity_decrease": trial.suggest_float("min_impurity_decrease", 0.0, 0.05),  
        "splitter": trial.suggest_categorical("splitter", ["best", "random"]),  
        "class_weight": trial.suggest_categorical("class_weight", [None, "balanced"]),  
    }

    # Set up cross-validation
    kf = StratifiedKFold(n_splits=5, shuffle=True)
    valid_scores = []

    for train_idx, valid_idx in kf.split(X_train, y_train):
        X_train_cv, X_valid_cv = X_train.iloc[train_idx], X_train.iloc[valid_idx]
        y_train_cv, y_valid_cv = y_train.iloc[train_idx], y_train.iloc[valid_idx]
        
        model = DecisionTreeClassifier(**params) 
        model.fit(X_train_cv, y_train_cv)
 
        valid_acc = accuracy_score(y_valid_cv, model.predict(X_valid_cv))
        valid_scores.append(valid_acc)

    return np.mean(valid_scores)

# Run Optuna optimization
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

# Print best hyperparameters
print("Best parameters:", study.best_trial.params)

# Train final Decision Tree model with best parameters
best_params = study.best_trial.params
final_model = DecisionTreeClassifier(**best_params)
final_model.fit(X_train, y_train)

# Evaluate on test set
y_pred_final = final_model.predict(X_test)
print("Final Model Accuracy:", accuracy_score(y_test, y_pred_final))
# Out:
# [I 2025-10-27 19:44:29,035] A new study created in memory with name: no-name-078e4064-2e56-4140-9c90-44d97b361137
# [I 2025-10-27 19:44:29,081] Trial 0 finished with value: 0.6686131386861314 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.045487962516941705, 'splitter': 'random', 'class_weight': None}. Best is trial 0 with value: 0.6686131386861314.
# [I 2025-10-27 19:44:29,139] Trial 1 finished with value: 0.7445255474452555 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 0.5, 'max_leaf_nodes': 17, 'min_impurity_decrease': 0.047670258038642804, 'splitter': 'best', 'class_weight': None}. Best is trial 1 with value: 0.7445255474452555.
# [I 2025-10-27 19:44:29,182] Trial 2 finished with value: 0.7416058394160585 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 15, 'max_features': 0.5, 'max_leaf_nodes': 16, 'min_impurity_decrease': 0.039748467175056895, 'splitter': 'best', 'class_weight': None}. Best is trial 1 with value: 0.7445255474452555.
# [I 2025-10-27 19:44:29,233] Trial 3 finished with value: 0.759124087591241 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 'log2', 'max_leaf_nodes': 9, 'min_impurity_decrease': 0.000596380354705145, 'splitter': 'best', 'class_weight': None}. Best is trial 3 with value: 0.759124087591241.
# [I 2025-10-27 19:44:29,288] Trial 4 finished with value: 0.6948905109489051 and parameters: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 0.3, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.0007458534550169538, 'splitter': 'random', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.759124087591241.
# [I 2025-10-27 19:44:29,349] Trial 5 finished with value: 0.7532846715328467 and parameters: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 12, 'max_features': 0.3, 'max_leaf_nodes': 12, 'min_impurity_decrease': 0.007016025146824212, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.759124087591241.
# [I 2025-10-27 19:44:29,403] Trial 6 finished with value: 0.7474452554744525 and parameters: {'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 11, 'min_impurity_decrease': 0.04035159114733444, 'splitter': 'best', 'class_weight': None}. Best is trial 3 with value: 0.759124087591241.
# [I 2025-10-27 19:44:29,453] Trial 7 finished with value: 0.7664233576642335 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 0.5, 'max_leaf_nodes': 18, 'min_impurity_decrease': 0.0013174830071123911, 'splitter': 'best', 'class_weight': None}. Best is trial 7 with value: 0.7664233576642335.
# [I 2025-10-27 19:44:29,513] Trial 8 finished with value: 0.7401459854014599 and parameters: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 19, 'min_samples_leaf': 7, 'max_features': 0.5, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0.005141168973686489, 'splitter': 'random', 'class_weight': None}. Best is trial 7 with value: 0.7664233576642335.
# [I 2025-10-27 19:44:29,573] Trial 9 finished with value: 0.6715328467153284 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'max_leaf_nodes': 18, 'min_impurity_decrease': 0.01795522516726461, 'splitter': 'random', 'class_weight': 'balanced'}. Best is trial 7 with value: 0.7664233576642335.
# [I 2025-10-27 19:44:29,658] Trial 10 finished with value: 0.7401459854014598 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 15, 'min_impurity_decrease': 0.021572583825720956, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 7 with value: 0.7664233576642335.
# [I 2025-10-27 19:44:29,738] Trial 11 finished with value: 0.7649635036496351 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 'log2', 'max_leaf_nodes': 6, 'min_impurity_decrease': 0.013484174199939691, 'splitter': 'best', 'class_weight': None}. Best is trial 7 with value: 0.7664233576642335.
# [I 2025-10-27 19:44:29,808] Trial 12 finished with value: 0.7766423357664234 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_impurity_decrease': 0.0144676970773974, 'splitter': 'best', 'class_weight': None}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:29,887] Trial 13 finished with value: 0.7430656934306569 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_impurity_decrease': 0.031399403608612354, 'splitter': 'best', 'class_weight': None}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:29,949] Trial 14 finished with value: 0.7474452554744525 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_features': 'log2', 'max_leaf_nodes': 14, 'min_impurity_decrease': 0.012756014154451194, 'splitter': 'best', 'class_weight': None}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:30,008] Trial 15 finished with value: 0.745985401459854 and parameters: {'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.5, 'max_leaf_nodes': 10, 'min_impurity_decrease': 0.028571573649583758, 'splitter': 'best', 'class_weight': None}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:30,074] Trial 16 finished with value: 0.7766423357664234 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 'log2', 'max_leaf_nodes': 13, 'min_impurity_decrease': 0.009895277926494032, 'splitter': 'best', 'class_weight': None}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:30,141] Trial 17 finished with value: 0.7737226277372262 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': 'log2', 'max_leaf_nodes': 13, 'min_impurity_decrease': 0.011461288581714081, 'splitter': 'best', 'class_weight': None}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:30,211] Trial 18 finished with value: 0.6627737226277371 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'log2', 'max_leaf_nodes': 6, 'min_impurity_decrease': 0.017717968597504675, 'splitter': 'random', 'class_weight': 'balanced'}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:30,273] Trial 19 finished with value: 0.7693430656934307 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 'log2', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.02342720004635568, 'splitter': 'best', 'class_weight': None}. Best is trial 12 with value: 0.7766423357664234.
# [I 2025-10-27 19:44:30,333] Trial 20 finished with value: 0.7839416058394161 and parameters: {'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 'log2', 'max_leaf_nodes': 12, 'min_impurity_decrease': 0.008042959367526248, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,405] Trial 21 finished with value: 0.7503649635036496 and parameters: {'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 18, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_leaf_nodes': 12, 'min_impurity_decrease': 0.008965629511821968, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,473] Trial 22 finished with value: 0.743065693430657 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': 'log2', 'max_leaf_nodes': 13, 'min_impurity_decrease': 0.018838534196406104, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,541] Trial 23 finished with value: 0.7839416058394161 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 19, 'min_samples_leaf': 14, 'max_features': 'log2', 'max_leaf_nodes': 10, 'min_impurity_decrease': 0.005184345409011894, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,614] Trial 24 finished with value: 0.7737226277372262 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_impurity_decrease': 0.005902065661980545, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,681] Trial 25 finished with value: 0.7751824817518248 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 14, 'max_features': 0.3, 'max_leaf_nodes': 7, 'min_impurity_decrease': 0.014154601635515329, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,741] Trial 26 finished with value: 0.7474452554744525 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': None, 'max_leaf_nodes': 10, 'min_impurity_decrease': 0.004366556459626024, 'splitter': 'random', 'class_weight': 'balanced'}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,820] Trial 27 finished with value: 0.7649635036496351 and parameters: {'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_impurity_decrease': 0.01597190606101103, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,890] Trial 28 finished with value: 0.7635036496350365 and parameters: {'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 'log2', 'max_leaf_nodes': 8, 'min_impurity_decrease': 0.028342028798026074, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:30,941] Trial 29 finished with value: 0.7051094890510948 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 11, 'max_features': 'log2', 'max_leaf_nodes': 11, 'min_impurity_decrease': 0.009374394506624034, 'splitter': 'random', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,010] Trial 30 finished with value: 0.7737226277372262 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 13, 'max_features': 'log2', 'max_leaf_nodes': 7, 'min_impurity_decrease': 0.0037879552142985433, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,082] Trial 31 finished with value: 0.7649635036496351 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 'log2', 'max_leaf_nodes': 14, 'min_impurity_decrease': 0.010502938733527017, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,138] Trial 32 finished with value: 0.7766423357664234 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 'log2', 'max_leaf_nodes': 14, 'min_impurity_decrease': 0.007893643084806935, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,211] Trial 33 finished with value: 0.7562043795620438 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'log2', 'max_leaf_nodes': 16, 'min_impurity_decrease': 0.020263057160705533, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,276] Trial 34 finished with value: 0.7503649635036497 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_leaf_nodes': 11, 'min_impurity_decrease': 0.014907394340107977, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,358] Trial 35 finished with value: 0.7693430656934307 and parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_leaf_nodes': 9, 'min_impurity_decrease': 0.003468523078596252, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,425] Trial 36 finished with value: 0.7386861313868615 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 0.3, 'max_leaf_nodes': 15, 'min_impurity_decrease': 0.008315850098616136, 'splitter': 'best', 'class_weight': None}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,509] Trial 37 finished with value: 0.7781021897810219 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'max_leaf_nodes': 12, 'min_impurity_decrease': 9.082595274457171e-05, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,591] Trial 38 finished with value: 0.6218978102189782 and parameters: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'max_leaf_nodes': 9, 'min_impurity_decrease': 0.0030575773784074375, 'splitter': 'random', 'class_weight': 'balanced'}. Best is trial 20 with value: 0.7839416058394161.
# [I 2025-10-27 19:44:31,684] Trial 39 finished with value: 0.7956204379562043 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'max_leaf_nodes': 12, 'min_impurity_decrease': 0.00023875708653757922, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 39 with value: 0.7956204379562043.
# [I 2025-10-27 19:44:31,781] Trial 40 finished with value: 0.7693430656934306 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'max_leaf_nodes': 11, 'min_impurity_decrease': 0.000524181485636935, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 39 with value: 0.7956204379562043.
# [I 2025-10-27 19:44:31,875] Trial 41 finished with value: 0.7489051094890511 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'max_leaf_nodes': 12, 'min_impurity_decrease': 0.0013337556011768677, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 39 with value: 0.7956204379562043.
# [I 2025-10-27 19:44:31,971] Trial 42 finished with value: 0.762043795620438 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'max_leaf_nodes': 12, 'min_impurity_decrease': 0.006194566974191014, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 39 with value: 0.7956204379562043.
# [I 2025-10-27 19:44:32,062] Trial 43 finished with value: 0.7985401459854014 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_impurity_decrease': 0.0022114149108786417, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 43 with value: 0.7985401459854014.
# [I 2025-10-27 19:44:32,140] Trial 44 finished with value: 0.7489051094890512 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_impurity_decrease': 9.355411638903299e-05, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 43 with value: 0.7985401459854014.
# [I 2025-10-27 19:44:32,226] Trial 45 finished with value: 0.7781021897810219 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_leaf_nodes': 11, 'min_impurity_decrease': 0.002355421228520094, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 43 with value: 0.7985401459854014.
# [I 2025-10-27 19:44:32,293] Trial 46 finished with value: 0.7547445255474453 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'max_leaf_nodes': 9, 'min_impurity_decrease': 0.03581982735756459, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 43 with value: 0.7985401459854014.
# [I 2025-10-27 19:44:32,374] Trial 47 finished with value: 0.635036496350365 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_leaf_nodes': 13, 'min_impurity_decrease': 0.00655966924578346, 'splitter': 'random', 'class_weight': 'balanced'}. Best is trial 43 with value: 0.7985401459854014.
# [I 2025-10-27 19:44:32,458] Trial 48 finished with value: 0.7284671532846716 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 13, 'max_features': 0.5, 'max_leaf_nodes': 12, 'min_impurity_decrease': 0.04514463787127653, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 43 with value: 0.7985401459854014.
# [I 2025-10-27 19:44:32,541] Trial 49 finished with value: 0.759124087591241 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'max_leaf_nodes': 11, 'min_impurity_decrease': 0.005099128701253398, 'splitter': 'best', 'class_weight': 'balanced'}. Best is trial 43 with value: 0.7985401459854014.
# Best parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'min_impurity_decrease': 0.0022114149108786417, 'splitter': 'best', 'class_weight': 'balanced'}
# Final Model Accuracy: 0.7674418604651163

# %%
test_accuracies = []
train_accuracies = []

for _ in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
    
    best_params = study.best_trial.params

    # Initialize the Decision Tree model
    final_model = DecisionTreeClassifier(**best_params)


    final_model.fit(X_train, y_train)


    test_accuracy = final_model.score(X_test, y_test)
    train_accuracy = final_model.score(X_train, y_train)
    #print("Train Accuracy:", train_accuracy)
    #print("Test Accuracy:", test_accuracy)

    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

print(np.mean(train_accuracies), np.mean(test_accuracies))
# Out:
# 0.7927007299270074 0.7755813953488373

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# Get best hyperparameters from Optuna study
best_params = study.best_trial.params
# Initialize the Decision Tree model
final_model = DecisionTreeClassifier(**best_params)

# Fit the model
final_model.fit(X_train, y_train)
print("Train Accuracy:", final_model.score(X_train, y_train))
print("Test Accuracy:", final_model.score(X_test, y_test))

# Predictions
y_pred = final_model.predict(X_test)

# Metrics
precision = precision_score(y_test, y_pred, average='binary')
recall = recall_score(y_test, y_pred, average='binary')
f1 = f1_score(y_test, y_pred, average='binary')

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Train Accuracy: 0.7708029197080292
# Test Accuracy: 0.7441860465116279
# Precision: 0.6590909090909091
# Recall: 0.8055555555555556
# F1 Score: 0.725

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.model_selection import learning_curve

# Get best hyperparameters from Optuna study
best_params = study.best_trial.params
best_params.pop("use_max_leaf_nodes", None)  # Remove invalid key

# Initialize the Decision Tree model
final_model = DecisionTreeClassifier(**best_params)

# Fit the model
final_model.fit(X_train, y_train)

# Evaluate final model on test data
y_pred_final = final_model.predict(X_test)
print("Final Model Accuracy on Test:", accuracy_score(y_test, y_pred_final))


# Compute learning curves
train_sizes, train_scores, validation_scores = learning_curve(
    final_model, X_train, y_train, cv=5, n_jobs=-1, scoring='accuracy',
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
validation_mean = np.mean(validation_scores, axis=1)
validation_std = np.std(validation_scores, axis=1)

# Plot Learning Curve
plt.figure(figsize=(12, 6))
plt.plot(train_sizes, train_mean, label='Training Accuracy', color='blue')
plt.plot(train_sizes, validation_mean, label='Validation Accuracy', color='green')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color='blue', alpha=0.2)
plt.fill_between(train_sizes, validation_mean - validation_std, validation_mean + validation_std, color='green', alpha=0.2)
plt.title('Learning Curve (Training vs Validation Accuracy)')
plt.xlabel('Training Size')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


# Ensure model supports predict_proba (classification case)
if hasattr(final_model, "predict_proba"):
    y_proba = final_model.predict_proba(X_test)[:, 1]  # Get probabilities for positive class

    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    roc_auc = auc(fpr, tpr)

    # Plot ROC Curve
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random guess line
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()
else:
    print("ROC curve cannot be plotted. Model does not support probability predictions.")
# Out:
# Final Model Accuracy on Test: 0.7151162790697675

# %%
explainer = shap.TreeExplainer(final_model)
shap_values = explainer.shap_values(X_train)  # Shape: (samples, features, 2)

# %%
shap.summary_plot(shap_values[:,:,1], X_train)

# %%
import joblib

joblib.dump(final_model, 'dt_model.pkl')

print("Model saved successfully!")
# Out:
# Model saved successfully!
